# %%
import numpy as np
# %pip install pandas
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/ae/d9/3741b344f57484b423cd22194025a8489992ad9962196a62721ef9980045/pandas-2.1.4-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl.metadata
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# ...
#    ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.5 MB 487.6 kB/s eta 0:00:22
#    ---------------------------------------- 0.1/10.5 MB 871.5 kB/s eta 0:00:12
#     --------------------------------------- 0.1/10.5 MB 944.1 kB/s eta 0:00:11
# ...

# %%
import pandas as pd
data = pd.read_csv('Survey regarding layover time (Responses) - Form Responses 1.csv')
data

# %%
data.columns
# Out:
# Index(['Timestamp', 'One Galle Face  [Morning (6.00 AM - 12.00 PM)]',
#        'One Galle Face  [Evening (12.00 PM - 6.00 PM)]',
#        'One Galle Face  [Night (6.00 PM - 12.00 AM)]',
#        'Colombo City Center (CCC) [Morning (6.00 AM - 12.00 PM)]',
#        'Colombo City Center (CCC) [Evening (12.00 PM - 6.00 PM)]',
#        'Colombo City Center (CCC) [Night (6.00 PM - 12.00 AM)]',
#        'Galle Face Green [Morning (6.00 AM - 12.00 PM)]',
#        'Galle Face Green [Evening (12.00 PM - 6.00 PM)]',
#        'Galle Face Green [Night (6.00 PM - 12.00 AM)]',
#        'Gangaramaya Temple [Morning (6.00 AM - 12.00 PM)]',
#        'Gangaramaya Temple [Evening (12.00 PM - 6.00 PM)]',
#        'Gangaramaya Temple [Night (6.00 PM - 12.00 AM)]',
#        'National Museum of Colombo [Morning (6.00 AM - 12.00 PM)]',
#        'National Museum of Colombo [Evening (12.00 PM - 6.00 PM)]',
#        'National Museum of Colombo [Night (6.00 PM - 12.00 AM)]',
# ...

# %%
data.drop(["Timestamp", "Are you from Sri Lanka? ", "If not, which country are you from? ", "How often do you travel and visit places?", "Consent notice"], axis = 1, inplace = True)

# %%
data.columns
# Out:
# Index(['One Galle Face  [Morning (6.00 AM - 12.00 PM)]',
#        'One Galle Face  [Evening (12.00 PM - 6.00 PM)]',
#        'One Galle Face  [Night (6.00 PM - 12.00 AM)]',
#        'Colombo City Center (CCC) [Morning (6.00 AM - 12.00 PM)]',
#        'Colombo City Center (CCC) [Evening (12.00 PM - 6.00 PM)]',
#        'Colombo City Center (CCC) [Night (6.00 PM - 12.00 AM)]',
#        'Galle Face Green [Morning (6.00 AM - 12.00 PM)]',
#        'Galle Face Green [Evening (12.00 PM - 6.00 PM)]',
#        'Galle Face Green [Night (6.00 PM - 12.00 AM)]',
#        'Gangaramaya Temple [Morning (6.00 AM - 12.00 PM)]',
#        'Gangaramaya Temple [Evening (12.00 PM - 6.00 PM)]',
#        'Gangaramaya Temple [Night (6.00 PM - 12.00 AM)]',
#        'National Museum of Colombo [Morning (6.00 AM - 12.00 PM)]',
#        'National Museum of Colombo [Evening (12.00 PM - 6.00 PM)]',
#        'National Museum of Colombo [Night (6.00 PM - 12.00 AM)]',
# ...

# %%
data.rename(columns= {'One Galle Face  [Morning (6.00 AM - 12.00 PM)]':'OGF [M]'}, inplace = True)
data.columns
data
# Out:
#               OGF [M] One Galle Face  [Evening (12.00 PM - 6.00 PM)]  \
# 0   More than 3 hours                                    2 - 3 hours
# 1         1 - 2 hours                                    1 - 2 hours
# 2         2 - 3 hours                              More than 3 hours
# 3         2 - 3 hours                                    2 - 3 hours
# 4         2 - 3 hours                                    2 - 3 hours
# 5    Less than 1 hour                                    2 - 3 hours
# 6         1 - 2 hours                                    2 - 3 hours
# 7         1 - 2 hours                              More than 3 hours
# 8         1 - 2 hours                                    2 - 3 hours
# 9         1 - 2 hours                              More than 3 hours
# 10      Never visited                               Less than 1 hour
# 11      Never visited                                    1 - 2 hours
# 12      Never visited                                    1 - 2 hours
# ...
