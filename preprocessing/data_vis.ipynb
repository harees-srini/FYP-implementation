# %%
# %pip install matplotlib
# %pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/160.8 kB ? eta -:--:--
#      ------- -------------------------------- 30.7/160.8 kB ? eta -:--:--
#      ------- -------------------------------- 30.7/160.8 kB ? eta -:--:--
#      ------- -------------------------------- 30.7/160.8 kB ? eta -:--:--
#      ------- -------------------------------- 30.7/160.8 kB ? eta -:--:--
#      ------- -------------------------------- 30.7/160.8 kB ? eta -:--:--
#      ------- -------------------------------- 30.7/160.8 kB ? eta -:--:--
#      -------------- ---------------------- 61.4/160.8 kB 164.1 kB/s eta 0:00:01
#      -------------- ---------------------- 61.4/160.8 kB 164.1 kB/s eta 0:00:01
#      ------------------ ------------------ 81.9/160.8 kB 183.8 kB/s eta 0:00:01
#      ------------------ ------------------ 81.9/160.8 kB 183.8 kB/s eta 0:00:01
#      ------------------ ------------------ 81.9/160.8 kB 183.8 kB/s eta 0:00:01
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
data = pd.read_csv("organized_data_encoded.csv")
data
# Out:
#       Unnamed: 0  stayTime_1 - 2 hours  stayTime_2 - 3 hours  \
# 0              0                 False                 False
# 1              1                 False                  True
# 2              2                 False                 False
# 3              3                 False                  True
# 4              4                 False                  True
# ...          ...                   ...                   ...
# 2155        2155                 False                 False
# 2156        2156                 False                 False
# 2157        2157                  True                 False
# 2158        2158                  True                 False
# 2159        2159                  True                 False
#
#       stayTime_Less than 1 hour  stayTime_More than 3 hours  \
# 0                         False                        True
# 1                         False                       False
# ...

# %%
# Create boxplots of stay time grouped by time of day
sns.boxplot(x = "timeOfDay", y = "stayTime", showmeans=True, data=data)
plt.xlabel('Time of Day')
plt.ylabel('Stay Time')
plt.title('Boxplot of Stay Time by Time of Day')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\IIT\FYP\Implementation_Code\data_vis.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/d%3A/IIT/FYP/Implementation_Code/data_vis.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> # Create boxplots of stay time grouped by time of day
# ----> <a href='vscode-notebook-cell:/d%3A/IIT/FYP/Implementation_Code/data_vis.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> sns.boxplot(x = "timeOfDay", y = "stayTime", showmeans=True, data=data)
#       <a href='vscode-notebook-cell:/d%3A/IIT/FYP/Implementation_Code/data_vis.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> plt.xlabel('Time of Day')
#       <a href='vscode-notebook-cell:/d%3A/IIT/FYP/Implementation_Code/data_vis.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> plt.ylabel('Stay Time')
#
# ...

# %%
# Create the heatmap
sns.heatmap(stay_time_matrix, cmap='coolwarm', annot=True, fmt='g')
plt.xlabel('Stay Time')
plt.ylabel('Location')
plt.title('Heatmap of Stay Time by Location')
plt.show()
